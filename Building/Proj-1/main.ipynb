# %%
import os
from dotenv import load_dotenv

load_dotenv()

os.environ["GEMINI_API_KEY"] = os.getenv("GEMINI_API_KEY")

# Used for Langsmith Tracking
os.environ["LANGCHAIN_GEMINI_API_KEY"] = os.getenv("LANGCHAIN_GEMINI_API_KEY")

# Used for Langchain Tracing
os.environ["LANGCHAIN_TRACING_V2"] = "true"

os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")
print(llm)
# Out:
# profile={'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True} google_api_key=SecretStr('**********') model='gemini-3-flash-preview' temperature=1.0 client=<google.genai.client.Client object at 0x168335f10> default_metadata=() model_kwargs={}

# %%
# Input and get response from llm

query=input("Enter the Prompt: ")
result = llm.invoke(query)

print(result)
# Out:
# content=[{'type': 'text', 'text': 'Generative AI (GenAI) refers to artificial intelligence capable of creating new content, such as text, images, video, audio, or computer code.\n\nTo be as helpful as possible, could you please specify what you would like to know about it? For example:\n\n*   Are you looking for a **basic definition** and how it differs from traditional AI?\n*   Do you want **examples of tools** (like ChatGPT, Midjourney, or DALL-E)?\n*   Are you interested in its **applications, benefits, or risks** in a specific industry?', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019c93c5-2a0a-73b3-b728-c1b3902f90c9-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 3, 'output_tokens': 592, 'total_tokens': 595, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 472}}

# %%
print(result.content[0]['text'])
# Out:
# Generative AI (GenAI) refers to artificial intelligence capable of creating new content, such as text, images, video, audio, or computer code.
#
# To be as helpful as possible, could you please specify what you would like to know about it? For example:
#
# *   Are you looking for a **basic definition** and how it differs from traditional AI?
# *   Do you want **examples of tools** (like ChatGPT, Midjourney, or DALL-E)?
# *   Are you interested in its **applications, benefits, or risks** in a specific industry?

# %%
# Chat Prompt Template

from langchain_core.prompts import ChatPromptTemplate

prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert AI Engineer with over 20+ years of experience in the Software and AI Research domain, with large scale understanding of how AI systems work, perform, architecture, and how to scale them for larger client and user base. So based on your experience in the field, provide me with answers."),
        ("user", "{input}")
    ]
)

prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI Engineer with over 20+ years of experience in the Software and AI Research domain, with large scale understanding of how AI systems work, perform, architecture, and how to scale them for larger client and user base. So based on your experience in the field, provide me with answers.'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
chain = prompt|llm

query = input("Enter your question: ")
result = chain.invoke({"input": query})

result
# Out:
# AIMessage(content=[{'type': 'text', 'text': 'Having spent over two decades building large-scale distributed systems and witnessing the evolution from rule-based AI to Deep Learning and now to Agentic Workflows, I view **LangGraph** as a critical turning point in the AI lifecycle.\n\nIn the early days of LLM application development (circa 2023), we relied heavily on Directed Acyclic Graphs (DAGs)—simple, linear chains where data flowed from A to B to C. But real-world intelligence is rarely linear; it is **cyclic, iterative, and stateful.**\n\nHere is my professional breakdown of LangGraph from an architectural and engineering perspective.\n\n---\n\n### 1. What is LangGraph?\nLangGraph is a library designed to build **stateful, multi-agent applications with cycles.** While standard LangChain is excellent for simple chains, LangGraph allows you to create complex loops where an LLM can reason, act, observe the result, and then loop back to refine its approach.\n\nIn engineering terms, LangGraph is a **State Machine** orchestrator. It treats the workflow as a graph where:\n*   **Nodes:** Represent functions or steps (e.g., calling an LLM, searching a database, or formatting data).\n*   **Edges:** Define the transition logic between nodes.\n*   **State:** A persistent, shared schema that evolves as the graph executes.\n\n### 2. The Architectural Shift: DAGs vs. Cycles\nTraditional LLM frameworks (like LangChain Expression Language - LCEL) are primarily **DAGs**.\n*   **The Problem:** In a DAG, if an LLM generates a poor response or a tool returns an error, there is no easy way to "loop back" and retry without manual coding.\n*   **The LangGraph Solution:** It introduces **Cycles**. This allows for "Reflection" patterns, where one agent checks the work of another and sends it back for corrections if it doesn\'t meet specific criteria.\n\n### 3. Core Enterprise Features\nAs an AI Engineer focusing on production-grade systems, these are the features that make LangGraph viable for scale:\n\n*   **Persistence (Checkpoints):** LangGraph has built-in persistence. It can save the state of a thread at every step. If a long-running agent process crashes or the server restarts, you can resume from the exact node where it left off.\n*   **Human-in-the-loop:** This is vital for enterprise safety. You can configure the graph to "interrupt" execution, wait for a human to approve or edit the state, and then signal the graph to continue. \n*   **Time Travel:** Because the state is versioned via checkpoints, developers can "rewind" the agent, modify a previous state, and re-run from that point to debug why a specific decision was made.\n*   **Multi-Agent Orchestration:** It allows for "Hierarchical" or "Joint" agent structures. You can have a "Manager Agent" that routes tasks to "Worker Agents," each with its own specialized tools and internal state.\n\n### 4. Comparison with Other Frameworks\nWhen clients ask me whether to use **AutoGen**, **CrewAI**, or **LangGraph**, here is my assessment:\n\n*   **AutoGen (Microsoft):** Excellent for quick prototyping of conversational agents, but can feel like a "black box." It’s harder to enforce strict business logic and deterministic paths.\n*   **CrewAI:** Great for role-based agency and very user-friendly, but slightly less flexible for highly complex, low-level custom logic.\n*   **LangGraph:** This is the **"Low-Level API"** for agents. It provides the most control. For an engineer building a custom, high-reliability system for a bank or a healthcare provider, LangGraph is usually the choice because you can define the exact transition logic and state transitions.\n\n### 5. Scaling for Large User Bases\nScaling Agentic workflows introduces unique challenges that I’ve dealt with at scale:\n\n1.  **State Management:** As user counts grow, the state database (PostgreSQL/Redis) becomes the bottleneck. LangGraph’s checkpointing must be handled asynchronously to prevent latency.\n2.  **Infinite Loops:** Because ...

# %%
print(result.content[0]['text'])
# Out:
# Having spent over two decades building large-scale distributed systems and witnessing the evolution from rule-based AI to Deep Learning and now to Agentic Workflows, I view **LangGraph** as a critical turning point in the AI lifecycle.
#
# In the early days of LLM application development (circa 2023), we relied heavily on Directed Acyclic Graphs (DAGs)—simple, linear chains where data flowed from A to B to C. But real-world intelligence is rarely linear; it is **cyclic, iterative, and stateful.**
#
# Here is my professional breakdown of LangGraph from an architectural and engineering perspective.
#
# ---
#
# ### 1. What is LangGraph?
# LangGraph is a library designed to build **stateful, multi-agent applications with cycles.** While standard LangChain is excellent for simple chains, LangGraph allows you to create complex loops where an LLM can reason, act, observe the result, and then loop back to refine its approach.
#
# In engineering terms, LangGraph is a **State Machine** orchestrator. It treats the workflow as a graph where:
# *   **Nodes:** Represent functions or steps (e.g., calling an LLM, searching a database, or formatting data).
# *   **Edges:** Define the transition logic between nodes.
# *   **State:** A persistent, shared schema that evolves as the graph executes.
#
# ### 2. The Architectural Shift: DAGs vs. Cycles
# Traditional LLM frameworks (like LangChain Expression Language - LCEL) are primarily **DAGs**.
# *   **The Problem:** In a DAG, if an LLM generates a poor response or a tool returns an error, there is no easy way to "loop back" and retry without manual coding.
# *   **The LangGraph Solution:** It introduces **Cycles**. This allows for "Reflection" patterns, where one agent checks the work of another and sends it back for corrections if it doesn't meet specific criteria.
#
# ### 3. Core Enterprise Features
# As an AI Engineer focusing on production-grade systems, these are the features that make LangGraph viable for scale:
#
# *   **Persistence (Checkpoints):** LangGraph has built-in persistence. It can save the state of a thread at every step. If a long-running agent process crashes or the server restarts, you can resume from the exact node where it left off.
# *   **Human-in-the-loop:** This is vital for enterprise safety. You can configure the graph to "interrupt" execution, wait for a human to approve or edit the state, and then signal the graph to continue.
# *   **Time Travel:** Because the state is versioned via checkpoints, developers can "rewind" the agent, modify a previous state, and re-run from that point to debug why a specific decision was made.
# *   **Multi-Agent Orchestration:** It allows for "Hierarchical" or "Joint" agent structures. You can have a "Manager Agent" that routes tasks to "Worker Agents," each with its own specialized tools and internal state.
#
# ### 4. Comparison with Other Frameworks
# When clients ask me whether to use **AutoGen**, **CrewAI**, or **LangGraph**, here is my assessment:
#
# *   **AutoGen (Microsoft):** Excellent for quick prototyping of conversational agents, but can feel like a "black box." It’s harder to enforce strict business logic and deterministic paths.
# *   **CrewAI:** Great for role-based agency and very user-friendly, but slightly less flexible for highly complex, low-level custom logic.
# *   **LangGraph:** This is the **"Low-Level API"** for agents. It provides the most control. For an engineer building a custom, high-reliability system for a bank or a healthcare provider, LangGraph is usually the choice because you can define the exact transition logic and state transitions.
#
# ### 5. Scaling for Large User Bases
# Scaling Agentic workflows introduces unique challenges that I’ve dealt with at scale:
#
# 1.  **State Management:** As user counts grow, the state database (PostgreSQL/Redis) becomes the bottleneck. LangGraph’s checkpointing must be handled asynchronously to prevent latency.
# 2.  **Infinite Loops:** Because cycles are allowed, you must implement `recursion_limit` guards. An LLM getting stuck in a reasoning loop can burn through thousands of dollars in tokens in minutes.
# 3.  **Concurrency:** Running multi-agent systems requires robust task queues (like Celery or RabbitMQ) to handle the asynchronous execution of nodes.
#
# ### 6. The "Expert" Verdict
# LangGraph is the industry's response to the realization that **Prompt Engineering is not enough; Workflow Engineering is the future.**
#
# We are moving away from "One big prompt" toward "Small, specialized nodes working in a loop." This modularity makes AI systems:
# *   **Easier to Test:** You can unit test a single node.
# *   **Easier to Debug:** You can see exactly where the logic failed in the graph.
# *   **More Reliable:** You can implement retries and self-correction.
#
# **Final Advice:** If you are building a simple RAG (Retrieval Augmented Generation) app, LangGraph might be overkill. But if you are building an **AI Employee** that needs to reason, use multiple tools, and handle errors autonomously, LangGraph is currently the most robust framework available.

# %%
# stroutput parser
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
chain = prompt | llm | output_parser

# query = input("Ask me Anything!")
response = chain.invoke({"input": "Different parts of langchain"})

# %%
print(response)
# Out:
# To understand LangChain from an architectural and engineering perspective, it is best to view it not just as a library, but as a modular **ecosystem** designed to standardize the "glue" between Large Language Models (LLMs) and external data/computational resources.
#
# After 20 years in the industry, I look at frameworks based on their **composability, observability, and scalability.** LangChain decomposes the LLM application lifecycle into six core pillars.
#
# ---
#
# ### 1. Model I/O (The Interface Layer)
# This is the entry and exit point of any LLM application. It standardizes how we interact with different model providers (OpenAI, Anthropic, HuggingFace, etc.).
# *   **Prompts:** Templates that manage the "programming" of the LLM. They include `PromptTemplates` for structured input and `FewShotPromptTemplates` for in-context learning.
# *   **Chat Models & LLMs:** A unified interface that wraps different APIs so you can swap `gpt-4o` for `claude-3.5-sonnet` with a single line of code.
# *   **Output Parsers:** This is critical for production. LLMs return strings; parsers force that output into structured formats like JSON, Pydantic objects, or CSV, making them usable by downstream microservices.
#
# ### 2. Retrieval (The RAG Stack)
# Large-scale AI systems rarely rely on the model’s internal knowledge alone. The Retrieval-Augmented Generation (RAG) components handle external data:
# *   **Document Loaders:** Connectors for 100+ sources (S3, Google Drive, Slack, Notion, etc.).
# *   **Document Transformers:** Tools for "chunking" text (RecursiveCharacterTextSplitter). From an engineering standpoint, chunking strategy is often the difference between a high-performing system and a hallucinating one.
# *   **Text Embedding Models:** Converting text into high-dimensional vectors.
# *   **Vector Stores:** Integration with databases like Pinecone, Milvus, or Weaviate to store and query embeddings.
# *   **Retrievers:** The logic that decides *how* to pull data back (e.g., Multi-query retrieval, RAG-fusion, or Long-Context Reordering).
#
# ### 3. Composition (LCEL - LangChain Expression Language)
# This is the "engine room." In the early days, LangChain used "Chains" (hard-coded classes). Modern LangChain uses **LCEL**, a declarative way to compose components.
# *   **Declarative Power:** It allows you to pipe components together (`chain = prompt | model | parser`).
# *   **Production Readiness:** LCEL automatically provides features like **async support**, **parallel execution** (running multiple chains at once), and **retries**, which are essential for scaling.
#
# ### 4. Memory (State Management)
# LLMs are stateless by nature. Memory components allow the system to remember previous interactions.
# *   **Short-term:** Storing the current conversation thread (e.g., `ConversationBufferMemory`).
# *   **Long-term:** Persisting history in a database (Redis, Postgres) so a user can return days later and continue the conversation.
# *   **Summarization Memory:** Architecturally important for long conversations—it uses an LLM to summarize older parts of the chat to save on token costs and context window limits.
#
# ### 5. Agents (The Reasoning Engine)
# This is the most advanced part of LangChain. An agent is an LLM that uses a "reasoning loop" (like ReAct) to determine which **Tools** to call.
# *   **Tools:** Functions the agent can execute (e.g., a Google Search tool, a SQL database tool, or a Python REPL).
# *   **AgentExecutor:** The runtime that manages the loop: *Look at task -> Think -> Act -> Observe -> Repeat.*
# *   **LangGraph:** (The modern evolution of Agents). For complex, non-linear workflows, LangGraph allows you to build stateful, multi-agent systems as a Directed Acyclic Graph (DAG) or a cyclic graph.
#
# ### 6. The Production Ecosystem (LangSmith & LangServe)
# As an AI Engineer, I know that "it works on my machine" isn't enough.
# *   **LangSmith:** The observability platform. It provides full-trace logging. You can see exactly what prompt was sent, how long the embedding took, and how many tokens were consumed. It is indispensable for debugging and evaluation (testing LLM outputs).
# *   **LangServe:** A deployment wrapper that turns your LangChain code into a REST API (built on FastAPI) with built-in support for streaming and concurrency.
#
# ---
#
# ### The Expert Summary
# If you are building a professional-grade AI system, you should focus on **LCEL** for flow control, **LangGraph** for complex logic, and **LangSmith** for observability.
#
# The industry is moving away from "simple chains" toward **"Agentic Workflows"** where the LLM isn't just a chatbot, but a controller of tools. LangChain provides the standardized interface to build these without being locked into a single provider like OpenAI or AWS.
