# %% [markdown]
# # Data Ingestion with Document Loaders
# - L1 of components of Langchain

# %%
 # Text Loader

 from langchain_community.document_loaders import TextLoader

 loader = TextLoader("speech.txt")
 print(loader)
# Out:
# <langchain_community.document_loaders.text.TextLoader object at 0x1056835c0>

# %%
text_document = loader.load()
print(text_document)
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Title: The Power of Small Actions\n\nGood morning everyone,\n\nToday, I want to talk about something simple yet incredibly powerful: small actions. In a world that constantly celebrates big achievements, viral moments, and overnight success stories, we often overlook the quiet strength of small, consistent efforts. Yet it is these small actions that shape our character, define our progress, and ultimately determine our success.\n\nThink about any meaningful accomplishment in your life. Whether it was passing an important exam, improving your health, building a relationship, or learning a new skill, it likely did not happen in a single dramatic moment. It happened through small, repeated steps. A few pages studied each night. A short walk taken every morning. A single honest conversation. These actions may have seemed insignificant at the time, but together they created lasting change.\n\nSmall actions matter because they are manageable. Big goals can feel overwhelming. When we focus only on the mountain ahead, we may feel discouraged before we even begin. But when we break that mountain into small, daily steps, progress becomes possible. A single step may not seem impressive, but it moves us forward. And forward, no matter how slow, is still progress.\n\nThere is also power in small acts of kindness. A smile, a word of encouragement, or a few minutes spent truly listening to someone can change the course of a person’s day. We may never fully know the impact of our kindness, but that does not make it any less meaningful. In fact, the smallest gestures often leave the deepest impressions.\n\nConsistency is what transforms small actions into powerful results. Anyone can take one step. The challenge is taking that step again tomorrow, and the day after that. When we commit to steady effort, we build discipline. When we build discipline, we build confidence. And when we build confidence, we begin to believe that greater goals are within reach.\n\nSo today, I encourage you not to wait for the perfect moment or the grand opportunity. Start small. Take one step toward your goal. Offer one act of kindness. Make one positive choice. Then repeat it.\n\nOver time, those small actions will tell a powerful story — the story of growth, resilience, and success. And one day, you will look back and realize that what once seemed small was actually the foundation of something extraordinary.\n\nThank you.\n')]

# %%
from langchain_community.document_loaders import PyPDFLoader

pdfloader = PyPDFLoader("paper.pdf")
print(pdfloader)
# Out:
# <langchain_community.document_loaders.pdf.PyPDFLoader object at 0x10d946c90>

# %%
docs = pdfloader.load()
print(docs)
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-02-12T09:26:52+00:00', 'author': '', 'keywords': '', 'moddate': '2026-02-12T09:26:52+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'paper.pdf', 'total_pages': 18, 'page': 0, 'page_label': '1'}, page_content='EXPERIMENTALSTUDY FORSMISHINGDETECTION INSMS\nMESSAGES\nDr. Subhas Barman\nHead of Dept., Research Mentor\nDepartment of Computer Science and Engineering\nJalpaiguri Government Engineering College, Jalpaiguri\nWest Bengal\nsubhas.barman@cse.jgec.ac.in\nAnurag Mukherjee\nDepartment of Computer Science and Engineering\nJalpaiguri Government Engineering College, Jalpaiguri\nWest Bengal\namdgp16@gmail.com\nRebanta Sarkar\nDepartment of Computer Science and Engineering\nJalpaiguri Government Engineering College, Jalpaiguri\nWest Bengal\nsarkarrebanta.2004@gmail.com\nArijit Roy\nDepartment of Computer Science and Engineering\nJalpaiguri Government Engineering College, Jalpaiguri\nWest Bengal\naroy6934@gmail.com\nFebruary 12, 2026\nABSTRACT\nSMS spam and smishing detection remains a critical challenge in automated content filtering systems,\noften addressed using black-box deep learning models. This work presents a unified comparison of\nclassical machine learning, ensemble, and deep learning approaches for three-class SMS classification\ninto ham, spam, and smishing. Classical and ensemble models use TF–IDF features, while deep\nmodels include a BiLSTM and a transformer-based BERT for semantic representation learning.\nExperiments are conducted on a balanced public dataset [ 1] under a consistent preprocessing and\nevaluation pipeline, comparing Logistic Regression, Multinomial Naïve Bayes, Linear SVM, Random\nForest, XGBoost, BiLSTM, and BERT. Results show that Linear SVM, Random Forest, and BiLSTM\nachieve the best overall performance, while simpler models remain competitive, highlighting trade-\noffs between accuracy, interpretability, and computational cost. This study offers practical guidance\nfor deploying effective SMS spam and smishing detection systems.\n1 Introduction\nThe widespread adoption of digital communication platforms such as email, messaging applications, and social\nmedia has led to a substantial increase in malicious messages, commonly referred to as spam and smishing. While\nspam primarily consists of unsolicited or promotional content, smishing poses a more serious threat by attempting to\ndeceive users into disclosing sensitive information or performing harmful actions. The growing volume and increasing\nsophistication of such messages make manual moderation impractical, thereby necessitating accurate and automated\ndetection systems capable of operating at scale [2, 3].\nMachine learning and deep learning techniques have become the dominant approaches for text-based spam detection\ndue to their ability to learn discriminative patterns from large datasets [4, 5]. However, many existing approaches rely\non complex models that function as black boxes, offering limited interpretability and increased computational cost.\nRecent work in related domains such as cyberbullying detection has highlighted the importance of interpretability and\ntransparency, for example through the use of Kolmogorov–Arnold Networks (KANs) and context-aware modeling with\nmetadata [6, 7]. These studies demonstrate that explainable and structured models can provide valuable insights beyond\nraw predictive performance.'), Document(metadata={'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-02-12T09:26:52+00:00', 'author': '', 'keywords': '', 'moddate': '2026-02-12T09:26:52+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'paper.pdf', 'total_p ...

# %%
print(docs[0].metadata)
# Out:
# {'producer': 'pdfTeX-1.40.27', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-02-12T09:26:52+00:00', 'author': '', 'keywords': '', 'moddate': '2026-02-12T09:26:52+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.141592653-2.6-1.40.27 (TeX Live 2025) kpathsea version 6.4.1', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'paper.pdf', 'total_pages': 18, 'page': 0, 'page_label': '1'}

# %%
print(docs[0].page_content)
# Out:
# EXPERIMENTALSTUDY FORSMISHINGDETECTION INSMS
# MESSAGES
# Dr. Subhas Barman
# Head of Dept., Research Mentor
# Department of Computer Science and Engineering
# Jalpaiguri Government Engineering College, Jalpaiguri
# West Bengal
# subhas.barman@cse.jgec.ac.in
# Anurag Mukherjee
# Department of Computer Science and Engineering
# Jalpaiguri Government Engineering College, Jalpaiguri
# West Bengal
# amdgp16@gmail.com
# Rebanta Sarkar
# Department of Computer Science and Engineering
# Jalpaiguri Government Engineering College, Jalpaiguri
# West Bengal
# sarkarrebanta.2004@gmail.com
# Arijit Roy
# Department of Computer Science and Engineering
# Jalpaiguri Government Engineering College, Jalpaiguri
# West Bengal
# aroy6934@gmail.com
# February 12, 2026
# ABSTRACT
# SMS spam and smishing detection remains a critical challenge in automated content filtering systems,
# often addressed using black-box deep learning models. This work presents a unified comparison of
# classical machine learning, ensemble, and deep learning approaches for three-class SMS classification
# into ham, spam, and smishing. Classical and ensemble models use TF–IDF features, while deep
# models include a BiLSTM and a transformer-based BERT for semantic representation learning.
# Experiments are conducted on a balanced public dataset [ 1] under a consistent preprocessing and
# evaluation pipeline, comparing Logistic Regression, Multinomial Naïve Bayes, Linear SVM, Random
# Forest, XGBoost, BiLSTM, and BERT. Results show that Linear SVM, Random Forest, and BiLSTM
# achieve the best overall performance, while simpler models remain competitive, highlighting trade-
# offs between accuracy, interpretability, and computational cost. This study offers practical guidance
# for deploying effective SMS spam and smishing detection systems.
# 1 Introduction
# The widespread adoption of digital communication platforms such as email, messaging applications, and social
# media has led to a substantial increase in malicious messages, commonly referred to as spam and smishing. While
# spam primarily consists of unsolicited or promotional content, smishing poses a more serious threat by attempting to
# deceive users into disclosing sensitive information or performing harmful actions. The growing volume and increasing
# sophistication of such messages make manual moderation impractical, thereby necessitating accurate and automated
# detection systems capable of operating at scale [2, 3].
# Machine learning and deep learning techniques have become the dominant approaches for text-based spam detection
# due to their ability to learn discriminative patterns from large datasets [4, 5]. However, many existing approaches rely
# on complex models that function as black boxes, offering limited interpretability and increased computational cost.
# Recent work in related domains such as cyberbullying detection has highlighted the importance of interpretability and
# transparency, for example through the use of Kolmogorov–Arnold Networks (KANs) and context-aware modeling with
# metadata [6, 7]. These studies demonstrate that explainable and structured models can provide valuable insights beyond
# raw predictive performance.
